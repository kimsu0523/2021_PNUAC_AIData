# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
cd "/content/drive/MyDrive/2021_AI"
# Out:
# /content/drive/MyDrive/2021_AI

# %%
pwd
# Out:
# '/content/drive/My Drive/2021_AI'

# %%
ls -al
# Out:
# total 4580
# -rw------- 1 root root    3991 Jul  8 13:38  01_codelab0_colab.ipynb
# -rw------- 1 root root   50250 Jul  6 14:34  02_python01.ipynb
# -rw------- 1 root root  374176 Jul  6 14:53  02_python02_matplotlib.ipynb
# -rw------- 1 root root   46560 Jul  8 16:43  03_pandas_01_series.ipynb
# -rw------- 1 root root  229914 Jul  7 03:24  04_pandas_02_dataframe.ipynb
# -rw------- 1 root root   22057 Jul  7 07:03  05_codelab1_json.ipynb
# -rw------- 1 root root   11342 Jul  7 08:40  06_codelab2_urllib.ipynb
# -rw------- 1 root root  229455 Jul  7 09:45  07_codelab3_bs.ipynb
# -rw------- 1 root root  948228 Jul 11 12:44  08_codelab4_seaborn.ipynb
# -rw------- 1 root root 1758228 Jul 11 14:41  09_codelab5_eda.ipynb
# -rw------- 1 root root  302471 Jul 12 15:35  10_codelab6_scikitlearn.ipynb
# -rw------- 1 root root  636330 Jul 12 15:49  11_codelab6_scikitlearn_실습.ipynb
# -rw------- 1 root root   19427 Jul  8 13:38  조별과제1.ipynb
# ...

# %%
# !git config --global user.email "mirrsogan@naver.com"

# %%
# !git config --global user.name "colab_kimsu"

# %%
# !git add ./

# %%
# !git status
# Out:
# On branch main
# Your branch is up to date with 'origin/main'.
#
# Changes to be committed:
#   (use "git reset HEAD <file>..." to unstage)
#
# 	modified:   01_codelab0_colab.ipynb
# 	modified:   02_python01.ipynb
# 	modified:   02_python02_matplotlib.ipynb
# 	modified:   03_pandas_01_series.ipynb
# 	modified:   04_pandas_02_dataframe.ipynb
# 	modified:   05_codelab1_json.ipynb
# 	modified:   06_codelab2_urllib.ipynb
# 	modified:   07_codelab3_bs.ipynb
# 	modified:   08_codelab4_seaborn.ipynb
# 	modified:   09_codelab5_eda.ipynb
# 	modified:   10_codelab6_scikitlearn.ipynb
# 	new file:   "11_codelab6_scikitlearn_\341\204\211\341\205\265\341\206\257\341\204\211\341\205\263\341\206\270.ipynb"
# 	modified:   "11_codelab6_scikitlearn_\354\213\244\354\212\265.ipynb"
# 	new file:   Untitled0 (1).ipynb
# 	new file:   Untitled0.ipynb
# 	new file:   Untitled1.ipynb
# 	modified:   data/news.csv
# ...

# %%
git commit -m ""
