# %% [markdown]
# #코랩연습 파일

# %% [markdown]
# ## **텍스트 셀**
# + 두 번 클릭하여 셀을 편집
# + 마크 다운 구문을 사용하여 작성
# + 마크 다운은 텍스트 기반의 마크업 언어
#  + * 반갑습니다 : [문법보기](https://colab.research.google.com/)

# %% [markdown]
# ## 코드셀

# %%
print('Hello Python!')
# Out:
# Hello Python!

# %%
x = 10

# %%
y = 20

# %%
print(f'{x}, {y}')
# Out:
# 10, 20
